# %% [markdown]
# # Tutorial 6

# %%
from maxplotlib import Canvas

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
c = Canvas(width="17cm", ratio=0.5)
sp = c.add_subplot(grid=False, xlabel="x", ylabel="y")
sp.add_line([0, 1, 2, 3], [0, 1, 0, 2], label="Line 1", layer=1, line_width=2.0)

c.show(backend="tikzpics")
# Out:
# len(self.subplots) = 1
# Plotting subplot at row 0, col 0
# line_plot = <maxplotlib.subfigure.line_plot.LinePlot object at 0x111b58350>
