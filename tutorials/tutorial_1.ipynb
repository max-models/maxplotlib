# %%
import maxplotlib.canvas.canvas as canvas

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
c
# Out:
# Canvas(nrows=1, ncols=1, caption=None, label=None)

# %%
c = canvas.Canvas(width=800, ratio=0.35)
sp = c.add_subplot(grid=True, xlabel='x (mm)', ylabel='10y',yscale=10,xshift=-10,xscale=0.1)
sp.add_line([0, 1, 2, 3], [0, 1, 4, 9], label="Line 1")
sp.add_line([0, 1, 2, 3], [0, 2, 3, 4], linestyle='dashed', color='red', label="Line 2")
c.plot()
c.savefig(filename='plot_00.pdf')

# %%
c = canvas.Canvas(ncols=2,nrows=2, width=800, ratio=0.5)
sp = c.add_subplot(grid=True)
c.add_subplot(row=1)
sp2 = c.add_subplot(row=1,legend=False)
sp.add_line([0, 1, 2, 3], [0, 1, 4, 9], label="Line 1")
sp2.add_line([0, 1, 2, 3], [0, 2, 3, 4], linestyle='dashed', color='red', label="Line 2")
c.plot()
c.savefig(filename='plot_01.pdf')

# %%
# Test with plotly backend
c = canvas.Canvas(width=800, ratio=0.35)
sp = c.add_subplot(grid=True, xlabel='x (mm)', ylabel='10y',yscale=10,xshift=-10,xscale=0.1)
sp.add_line([0, 1, 2, 3], [0, 1, 4, 9], label="Line 1", linestyle='-.')
sp.add_line([0, 1, 2, 3], [0, 2, 3, 4], linestyle='dashed', color='red', label="Line 2")
c.plot(backend='matplotlib')
c.plot(backend='plotly')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[41], line 7
#       5 sp.add_line([0, 1, 2, 3], [0, 2, 3, 4], linestyle='dashed', color='red', label="Line 2")
#       6 c.plot(backend='matplotlib')
# ----> 7 c.plot(backend='plotly')
#
# File ~/git_repos/maxplotlib/src/maxplotlib/canvas/canvas.py:85, in Canvas.plot(self, backend, show, savefig)
#      83     return self.plot_matplotlib(show=show, savefig=savefig)
#      84 elif backend == 'plotly':
# ---> 85     self.plot_plotly(show=show, savefig=savefig)
#
# File ~/git_repos/maxplotlib/src/maxplotlib/canvas/canvas.py:154, in Canvas.plot_plotly(self, show, savefig)
#     151         fig.add_trace(trace, row=row + 1, col=col + 1)
#     153 # Update layout settings
# --> 154 fig.update_layout(
#     155     width=fig_width,
#     156     height=fig_height,
#     157     font=dict(size=fontsize),
# ...
